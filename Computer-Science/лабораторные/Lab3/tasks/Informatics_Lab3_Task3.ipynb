# %% [markdown]
# ### 3. Необязательное задания на 20 баллов для получения оценки «5» (позволяет набрать до +20 баллов от максимального числа баллов БаРС за данную лабораторную, в файл Informatics_Lab3_Task3.py).
# 1) Реализуйте программный продукт на языке Python, используя регулярные выражения по варианту,
# представленному в таблице.
# 2) Для своей программы придумайте минимум 5 тестов. Все 5 тестов необходимо показать при
# защите.
# 3) Протестируйте свою программу на этих тестах.
# 4) Минимально использовать циклы и условия, основной частью решения должны быть
# регулярные выражения.
#
# Вам необходимо поменять падежи в тексте у прилагательных, которые встречаются
# несколько раз. На вход подаётся текст и порядковый номер слова, падежная форма
# которого будет использована для замены.
# Пример ввода:
#
# 1)Номер 2 <br>
# 2)Текст
# Текст: | Пример вывода:
# ------------------------------------------------------------| ------------------------------------------------------------
# Футбольн`ый` клуб «Реал Мадрид» является 15-кратным обладателем главного футбольн`ого` европейского трофея – Лиги Чемпионов. Данный турнир организован Союзом европейских футбольн`ых` ассоциаций (УЕФА). Идея о континентальном футбольн`ом` турнире пришла к журналисту Габриэлю Ано в 1955 году. | Футбольн`ого` клуб «Реал Мадрид» является 15-кратным обладателем главного футбольн`ого` европейского трофея – Лиги Чемпионов. Данный турнир организован Союзом европейских футбольн`ого` ассоциаций (УЕФА). Идея о континентальном футбольн`ого` турнире пришла к журналисту Габриэлю Ано в 1955 году.

# %%
#Informatics_Lab3_Task3.py
#Author = Эллити Мохамед Эмад Ахмед Авад
#Group = P3131
#Date = 05.10.2025

# %%
import re
from collections import Counter

adjective_endings = [
    'ый', 'ий', 'ой', 'ая', 'яя', 'ое', 'ее', 'ого', 'его', 'ой', 'ей',
    'ому', 'ему', 'ую', 'юю', 'ым', 'им', 'ыми', 'ими', 'ых', 'их', 'ые', 'ие', 'ом', 'ем'
]

def solve(text, number):
    # Find all adjective roots
    pattern = fr"\b(\w+)(?:{'|'.join(adjective_endings)})\b"
    words = re.findall(pattern, text.lower())
    
    if not words:
        return None
    if word_number > len(words) or word_number < 1:
        return "Invalid word number"
    
    # Most common adjective root
    most_common_root = Counter(words).most_common(1)[0][0]

    # Find all matches with full words
    full_pattern = fr"\b{most_common_root}(\w*)\b"
    matches = re.findall(full_pattern, text, flags=re.IGNORECASE)
    
    if len(matches) < number or number < 1:
        return None
    
    target_ending = matches[number - 1]

    def replacer(match):
        word = match.group(0)
        new_word = most_common_root + target_ending
        return new_word.capitalize()

    result = re.sub(full_pattern, replacer, text, flags=re.IGNORECASE)
    return result

# %%
tests = [
    ("Футбольный клуб «Реал Мадрид» является 15-кратным обладателем главного футбольного европейского трофея – Лиги Чемпионов. Данный турнир организован Союзом европейских футбольных ассоциаций (УЕФА). Идея о континентальном футбольном турнире пришла к журналисту Габриэлю Ано в 1955 году.", 2),
    ("Маленький мальчик играл на маленьком дворе. Его мама наблюдала за маленьким ребенком из окна.", 3),
    ("Старый профессор читал лекцию в старой аудитории. Студенты уважали старого учителя за его знания.", 3),
    ("Красивый сад расположен рядом с красивым прудом.Посетители наслаждались красивым ландшафтом.", 1),
    ("Новый музей открылся в новом здании. Экспозиции в новом музее привлекали много туристов.", 2),
]
expectTests = [
    # Test 1
    "Футбольного клуб «Реал Мадрид» является 15-кратным обладателем главного футбольного европейского трофея – Лиги Чемпионов. Данный турнир организован Союзом европейских футбольного ассоциаций (УЕФА). Идея о континентальном футбольного турнире пришла к журналисту Габриэлю Ано в 1955 году.",
    
    # Test 2
    "Маленьким мальчик играл на маленьким дворе. Его мама наблюдала за маленьким ребенком из окна.",
    
    # Test 3
    "Старого профессор читал лекцию в старого аудитории. Студенты уважали старого учителя за его знания.",
    
    # Test 4
    "Красивый сад расположен рядом с красивый прудом.Посетители наслаждались красивый ландшафтом.",
    
    # Test 5
    "Новом музей открылся в новом здании. Экспозиции в новом музее привлекали много туристов."
]

for i, (text, word_number) in enumerate(tests, 1):
    print(f"\n=== Test {i} ===")
    print("Original text:")
    print(text)
    
    processed_text = replace_adjective_endings(text, word_number)  # <-- use correct function

    print("\nProcessed text:")
    print(processed_text)
    
    expected_text = expectTests[i-1]
    print("\nExpected text:")
    print(expected_text)
    
    if processed_text == expected_text:
        print("\n✅ Test passed")
    else:
        print("\n❌ Test failed")
# Out:
# === Test 1 ===
# Original text:
# Футбольный клуб «Реал Мадрид» является 15-кратным обладателем главного футбольного европейского трофея – Лиги Чемпионов. Данный турнир организован Союзом европейских футбольных ассоциаций (УЕФА). Идея о континентальном футбольном турнире пришла к журналисту Габриэлю Ано в 1955 году.
#
# Processed text:
# Футбольного клуб «Реал Мадрид» является 15-кратным обладателем главного футбольного европейского трофея – Лиги Чемпионов. Данный турнир организован Союзом европейских футбольного ассоциаций (УЕФА). Идея о континентальном футбольного турнире пришла к журналисту Габриэлю Ано в 1955 году.
#
# Expected text:
# Футбольного клуб «Реал Мадрид» является 15-кратным обладателем главного футбольного европейского трофея – Лиги Чемпионов. Данный турнир организован Союзом европейских футбольного ассоциаций (УЕФА). Идея о континентальном футбольного турнире пришла к журналисту Габриэлю Ано в 1955 году.
#
# ✅ Test passed
#
# === Test 2 ===
# Original text:
# Маленький мальчик играл на маленьком дворе. Его мама наблюдала за маленьким ребенком из окна.
#
# Processed text:
# Маленьким мальчик играл на маленьким дворе. Его мама наблюдала за маленьким ребенком из окна.
#
# Expected text:
# Маленьким мальчик играл на маленьким дворе. Его мама наблюдала за маленьким ребенком из окна.
#
# ✅ Test passed
#
# === Test 3 ===
# Original text:
# Старый профессор читал лекцию в старой аудитории. Студенты уважали старого учителя за его знания.
#
# Processed text:
# Старого профессор читал лекцию в старого аудитории. Студенты уважали старого учителя за его знания.
#
# Expected text:
# Старого профессор читал лекцию в старого аудитории. Студенты уважали старого учителя за его знания.
#
# ✅ Test passed
#
# === Test 4 ===
# Original text:
# Красивый сад расположен рядом с красивым прудом.Посетители наслаждались красивым ландшафтом.
#
# Processed text:
# Красивый сад расположен рядом с красивый прудом.Посетители наслаждались красивый ландшафтом.
#
# Expected text:
# Красивый сад расположен рядом с красивый прудом.Посетители наслаждались красивый ландшафтом.
#
# ✅ Test passed
#
# === Test 5 ===
# Original text:
# Новый музей открылся в новом здании. Экспозиции в новом музее привлекали много туристов.
#
# Processed text:
# Новом музей открылся в новом здании. Экспозиции в новом музее привлекали много туристов.
#
# Expected text:
# Новом музей открылся в новом здании. Экспозиции в новом музее привлекали много туристов.
#
# ✅ Test passed

# %%
print("=== Replace adjective forms using the reference word ===")
text_input = input("Enter the text: ")
word_number_input = int(input("Enter the reference word number: "))

result = replace_adjective_endings(text_input, word_number_input)
print("\nProcessed text:")
print(result)
# Out:
# === Replace adjective forms using the reference word ===
# Enter the text:  Футбольный клуб «Реал Мадрид» является 15-кратным обладателем главного футбольного европейского трофея – Лиги Чемпионов. Данный турнир организован Союзом европейских футбольных ассоциаций (УЕФА). Идея о континентальном футбольном турнире пришла к журналисту Габриэлю Ано в 1955 году
# Enter the reference word number:  2
# Processed text:
# Футбольного клуб «Реал Мадрид» является 15-кратным обладателем главного футбольного европейского трофея – Лиги Чемпионов. Данный турнир организован Союзом европейских футбольного ассоциаций (УЕФА). Идея о континентальном футбольного турнире пришла к журналисту Габриэлю Ано в 1955 году
