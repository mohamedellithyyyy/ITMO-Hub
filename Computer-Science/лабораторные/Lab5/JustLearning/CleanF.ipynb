# %%
import pandas as pd

# %%
# Read Excel (no headers)
df = pd.read_excel("./lab5.xlsx", sheet_name="Sheet2", header=None)

# %%
# Clean column 6 (index 5 because pandas is 0-based)
df[5] = None

# %%
# Save the cleaned file
df.to_excel("./mainCleaned.xlsx", header=False, index=False)

# %%
print("Column 6 (F) has been cleaned without deleting the column.")
