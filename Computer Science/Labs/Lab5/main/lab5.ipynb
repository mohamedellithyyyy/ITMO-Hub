# %%
import pandas as pd
from openpyxl.styles import Border, Side
from openpyxl import load_workbook

# %%
# Read file
df = pd.read_excel("lab5.xlsx", sheet_name="Sheet2", header=None)

# %%
# Clean column instead of deleting
# df[5] = None
df = df.drop(df.columns[5], axis=1)
print(df)
# Out:
#      0      1        2    3                    4     7     8    9    10    11  \
# 0    A=   2404      NaN  NaN                  NaN   NaN   NaN  NaN  NaN   NaN
# 1    C=  25449      NaN  NaN                  NaN   NaN   NaN  NaN  NaN   NaN
# 2   NaN    NaN      NaN  NaN                  NaN  14.0  13.0   12  NaN  11.0
# 3   X1=     A=   2404.0  NaN                B1 =    0.0   0.0    0    .   1.0
# 4   X2=     C=  25449.0  NaN                 B2 =   1.0   1.0    0    .   0.0
# ..  ...    ...      ...  ...                  ...   ...   ...  ...  ...   ...
# 65  NaN    NaN      NaN  NaN               B11(2)   0.0   1.0    0    .   0.0
# 66  NaN    NaN      NaN    +                B3(2)   1.0   1.0    0    .   1.0
# 67  NaN    NaN      NaN  NaN                  NaN   0.0   0.0    1    .   0.0
# 68  NaN    NaN      NaN  NaN  Перевод из доп кода   NaN   NaN  NaN    .   NaN
# 69  NaN    NaN      NaN  NaN                  NaN   1.0   NaN  PF=    0   NaN
#
#     ...    27       28       29   30  31  \
# 0   ...   NaN      NaN      NaN  NaN NaN
# 1   ...   NaN      NaN      NaN  NaN NaN
# 2   ...   NaN      NaN      NaN  NaN NaN
# 3   ...   NaN      NaN      NaN  NaN NaN
# 4   ...   NaN      NaN      NaN  NaN NaN
# ..  ...   ...      ...      ...  ...  ..
# 65  ...   NaN  X11(10) -23045.0  NaN NaN
# 66  ...     +   X3(10)  27853.0  NaN NaN
# 67  ...  (10)      NaN   4808.0  NaN NaN
# 68  ...   NaN      NaN      NaN  NaN NaN
# 69  ...   NaN      NaN      NaN  NaN NaN
#
#                                                    32  33  34  35   36
# 0                                                 NaN NaN NaN NaN  NaN
# 1                                Результат корректный NaN NaN NaN  NaN
# 2   При сложении двух положительных чисел получен ... NaN NaN NaN  NaN
# 3   Результат корректный, перенос из старшего разр... NaN NaN NaN  NaN
# 4   При сложении двух отрицательных чисел получен ... NaN NaN NaN  NaN
# ..                                                ...  ..  ..  ..  ...
# 65                                                NaN NaN NaN NaN  NaN
# 66  Результат корректный, перенос из старшего разр... NaN NaN NaN  NaN
# 67                                                NaN NaN NaN NaN  NaN
# 68                                                NaN NaN NaN NaN  NaN
# 69                                                NaN NaN NaN NaN  NaN
#
# [70 rows x 35 columns]

# %%
# Save temporary
temp_path = "../output/output.xlsx"
df.to_excel(temp_path, index=False, header=False)
